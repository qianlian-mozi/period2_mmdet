# %%
# !python demo/image_demo.py data/test/R.jpg work_dirs/balloon_rtmdet/balloon_rtmdet.py --weights work_dirs/balloon_rtmdet/best_coco/bbox_mAP_epoch_170.pth
# Out:
# Loads checkpoint by local backend from path: work_dirs/balloon_rtmdet/best_coco/bbox_mAP_epoch_170.pth
# 06/10 18:59:40 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 06/10 18:59:40 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 06/10 18:59:44 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# 06/10 18:59:44 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /root/miniconda3/lib/python3.8/site-packages/torch/functional.py:445: ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ...

# %%
from PIL import Image
Image.open('data/test/R.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=850x478 at 0x7FDF804D6820>

# %%
Image.open('outputs/vis/R.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=850x478 at 0x7FDF804DB3A0>
